# %% [markdown]
# ## 01-03-2025
#
# # Module 5:
#
# **Purpose:**
#
# **Trains on DISCOVERY SET ONLY (n=8)**
# - Discovery: 4 ALS, 4 Control
# - Validation: **LOCKED**

# %%
import pandas as pd
import joblib
from src.classification import train_classifier
from src.config import TRAINED_MODEL_FILE

# %%
models = {}

for clf_type in ['logistic', 'random_forest']:
    model, X_train, y_train = train_classifier(clf_type)
    models[clf_type] = model
# Out:
# ✓ logistic model saved to: /Users/maggiebrown/Desktop/PrimaMente/wgbs_classifier/results/classification/logistic_classifier.joblib
# ✓ random_forest model saved to: /Users/maggiebrown/Desktop/PrimaMente/wgbs_classifier/results/classification/random_forest_classifier.joblib
