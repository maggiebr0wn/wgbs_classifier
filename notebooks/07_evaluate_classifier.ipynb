# %% [markdown]
# ## 01-03-2025
#
# # Module 6:
#
# **Purpose:**
#
# **Tests on VALIDATION SET (n=14)**
# - Discovery: 4 ALS, 4 Control
# - Validation: 8 ALS, 6 Control

# %%
import pandas as pd
from src.evaluation import validation_pca_df, models, evaluate_models

# %%
eval_results = evaluate_models(validation_pca_df, models)

# %%
# Print results
for clf_name, metrics in eval_results.items():
    print(f"\nClassifier: {clf_name}")
    print(f"Accuracy: {metrics['accuracy']:.2f}")
    print(f"ROC AUC: {metrics['roc_auc']}")
    print("Confusion Matrix:")
    print(metrics['confusion_matrix'])
# Out:
# Classifier: logistic
# Accuracy: 0.36
# ROC AUC: 0.3958333333333333
# Confusion Matrix:
# [[3 3]
#  [6 2]]
#
# Classifier: random_forest
# Accuracy: 0.29
# ROC AUC: 0.29166666666666663
# Confusion Matrix:
# [[3 3]
#  [7 1]]
